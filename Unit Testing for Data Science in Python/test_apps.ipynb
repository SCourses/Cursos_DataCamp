# %% [markdown]
# ## Unit test

# %% [markdown]
# Unit Testing for Data Science in Python
#
# ![image.png](attachment:image.png)
#
# Many data scientists do not think much about testing, and just do it in the manual way when necessary. But once you see the big picture i.e. the life cycle of a function over the entire project, you appreciate how important testing really is and how frequently you need to test things.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# our project directory is
#
# ![image.png](attachment:image.png)
#
# our module is a function than conver float to int an we eant test the function, in this case we create a python test file to test this module
#
# ![image-2.png](attachment:image-2.png)
#
# in this code we probe the funtion wirh pytest
#
# ![image-3.png](attachment:image-3.png)
#
# if assert is equal to False
#
# ![image-4.png](attachment:image-4.png)
#
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## Intermediate unit testing

# %% [markdown]
# we can add a mesage from assertion error, iths only if we have a False statement in assert
#
# ![image.png](attachment:image.png)
#
# the Assertion erro show is
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Testing float return values

# %% [markdown]
# the problem with float numbers is for example 0.1+0.1+0.1==0.3 return false because (0.1+0.1+0.1)==0.3000004, in this case we can use
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Testing with multiple assert statements
#
# we can work with one more asser statement in a test funcion, this test passed if asset all asert funcions are equal than true
#
# there is an example to test multimple assert sataement
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Unit test a ValueError
# we can test the error mesage in our function
#
# ![image.png](attachment:image.png)
#
# this is a example to verify if message error is "Argument data_array must have at least 2 rows, it actually has just 1" if the array input is one dimentional
